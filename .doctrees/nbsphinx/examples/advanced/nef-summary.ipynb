# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book "Neural Engineering"](
# https://www.amazon.com/Neural-Engineering-Representation-Neurobiological-Computational/dp/0262550601).
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="479900741" href="javascript:toggle_input_479900741()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_479900741;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_479900741 = document.getElementById("479900741");
#                 var cell = link_479900741;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_479900741;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_479900741 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_479900741 = cell.previousElementSibling;
#                 }
#                 input_479900741.style.display = "none"; // hide
#
#                 toggle_input_479900741 = function() {
#                     if (input_479900741.style.display == "none") {
#                         input_479900741.style.display = ""; // show
#                         link_479900741.innerHTML = "Hide Input";
#                     } else {
#                         input_479900741.style.display = "none"; // hide
#                         link_479900741.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_479900741 = $("a[id='479900741']");
#                 var cell_479900741 = link_479900741.parents("div.cell:first");
#                 if (cell_479900741.length == 0) {
#                     cell_479900741 = link_479900741.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_479900741 = cell_479900741.children("div.input");
#                 if (input_479900741.length == 0) {
#                     input_479900741 = cell_479900741.prev("div.nbinput");
#                 }
#                 input_479900741.hide();
#
#                 toggle_input_479900741 = function() {
#                     if (input_479900741.is(':hidden')) {
#                         input_479900741.slideDown();
#                         link_479900741[0].innerHTML = "Hide Input";
#                     } else {
#                         input_479900741.slideUp();
#                         link_479900741[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="744620279" href="javascript:toggle_input_744620279()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_744620279;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_744620279 = document.getElementById("744620279");
#                 var cell = link_744620279;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_744620279;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_744620279 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_744620279 = cell.previousElementSibling;
#                 }
#                 input_744620279.style.display = "none"; // hide
#
#                 toggle_input_744620279 = function() {
#                     if (input_744620279.style.display == "none") {
#                         input_744620279.style.display = ""; // show
#                         link_744620279.innerHTML = "Hide Input";
#                     } else {
#                         input_744620279.style.display = "none"; // hide
#                         link_744620279.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_744620279 = $("a[id='744620279']");
#                 var cell_744620279 = link_744620279.parents("div.cell:first");
#                 if (cell_744620279.length == 0) {
#                     cell_744620279 = link_744620279.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_744620279 = cell_744620279.children("div.input");
#                 if (input_744620279.length == 0) {
#                     input_744620279 = cell_744620279.prev("div.nbinput");
#                 }
#                 input_744620279.hide();
#
#                 toggle_input_744620279 = function() {
#                     if (input_744620279.is(':hidden')) {
#                         input_744620279.slideDown();
#                         link_744620279[0].innerHTML = "Hide Input";
#                     } else {
#                         input_744620279.slideUp();
#                         link_744620279[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="1216305458" href="javascript:toggle_input_1216305458()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1216305458;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1216305458 = document.getElementById("1216305458");
#                 var cell = link_1216305458;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1216305458;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1216305458 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1216305458 = cell.previousElementSibling;
#                 }
#                 input_1216305458.style.display = "none"; // hide
#
#                 toggle_input_1216305458 = function() {
#                     if (input_1216305458.style.display == "none") {
#                         input_1216305458.style.display = ""; // show
#                         link_1216305458.innerHTML = "Hide Input";
#                     } else {
#                         input_1216305458.style.display = "none"; // hide
#                         link_1216305458.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1216305458 = $("a[id='1216305458']");
#                 var cell_1216305458 = link_1216305458.parents("div.cell:first");
#                 if (cell_1216305458.length == 0) {
#                     cell_1216305458 = link_1216305458.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1216305458 = cell_1216305458.children("div.input");
#                 if (input_1216305458.length == 0) {
#                     input_1216305458 = cell_1216305458.prev("div.nbinput");
#                 }
#                 input_1216305458.hide();
#
#                 toggle_input_1216305458 = function() {
#                     if (input_1216305458.is(':hidden')) {
#                         input_1216305458.slideDown();
#                         link_1216305458[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1216305458.slideUp();
#                         link_1216305458[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="2092160731" href="javascript:toggle_input_2092160731()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2092160731;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2092160731 = document.getElementById("2092160731");
#                 var cell = link_2092160731;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2092160731;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2092160731 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2092160731 = cell.previousElementSibling;
#                 }
#                 input_2092160731.style.display = "none"; // hide
#
#                 toggle_input_2092160731 = function() {
#                     if (input_2092160731.style.display == "none") {
#                         input_2092160731.style.display = ""; // show
#                         link_2092160731.innerHTML = "Hide Input";
#                     } else {
#                         input_2092160731.style.display = "none"; // hide
#                         link_2092160731.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2092160731 = $("a[id='2092160731']");
#                 var cell_2092160731 = link_2092160731.parents("div.cell:first");
#                 if (cell_2092160731.length == 0) {
#                     cell_2092160731 = link_2092160731.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2092160731 = cell_2092160731.children("div.input");
#                 if (input_2092160731.length == 0) {
#                     input_2092160731 = cell_2092160731.prev("div.nbinput");
#                 }
#                 input_2092160731.hide();
#
#                 toggle_input_2092160731 = function() {
#                     if (input_2092160731.is(':hidden')) {
#                         input_2092160731.slideDown();
#                         link_2092160731[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2092160731.slideUp();
#                         link_2092160731[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1572508292" href="javascript:toggle_input_1572508292()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1572508292;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1572508292 = document.getElementById("1572508292");
#                 var cell = link_1572508292;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1572508292;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1572508292 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1572508292 = cell.previousElementSibling;
#                 }
#                 input_1572508292.style.display = "none"; // hide
#
#                 toggle_input_1572508292 = function() {
#                     if (input_1572508292.style.display == "none") {
#                         input_1572508292.style.display = ""; // show
#                         link_1572508292.innerHTML = "Hide Input";
#                     } else {
#                         input_1572508292.style.display = "none"; // hide
#                         link_1572508292.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1572508292 = $("a[id='1572508292']");
#                 var cell_1572508292 = link_1572508292.parents("div.cell:first");
#                 if (cell_1572508292.length == 0) {
#                     cell_1572508292 = link_1572508292.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1572508292 = cell_1572508292.children("div.input");
#                 if (input_1572508292.length == 0) {
#                     input_1572508292 = cell_1572508292.prev("div.nbinput");
#                 }
#                 input_1572508292.hide();
#
#                 toggle_input_1572508292 = function() {
#                     if (input_1572508292.is(':hidden')) {
#                         input_1572508292.slideDown();
#                         link_1572508292[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1572508292.slideUp();
#                         link_1572508292[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="127904390" href="javascript:toggle_input_127904390()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_127904390;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_127904390 = document.getElementById("127904390");
#                 var cell = link_127904390;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_127904390;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_127904390 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_127904390 = cell.previousElementSibling;
#                 }
#                 input_127904390.style.display = "none"; // hide
#
#                 toggle_input_127904390 = function() {
#                     if (input_127904390.style.display == "none") {
#                         input_127904390.style.display = ""; // show
#                         link_127904390.innerHTML = "Hide Input";
#                     } else {
#                         input_127904390.style.display = "none"; // hide
#                         link_127904390.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_127904390 = $("a[id='127904390']");
#                 var cell_127904390 = link_127904390.parents("div.cell:first");
#                 if (cell_127904390.length == 0) {
#                     cell_127904390 = link_127904390.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_127904390 = cell_127904390.children("div.input");
#                 if (input_127904390.length == 0) {
#                     input_127904390 = cell_127904390.prev("div.nbinput");
#                 }
#                 input_127904390.hide();
#
#                 toggle_input_127904390 = function() {
#                     if (input_127904390.is(':hidden')) {
#                         input_127904390.slideDown();
#                         link_127904390[0].innerHTML = "Hide Input";
#                     } else {
#                         input_127904390.slideUp();
#                         link_127904390[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1723306425" href="javascript:toggle_input_1723306425()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1723306425;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1723306425 = document.getElementById("1723306425");
#                 var cell = link_1723306425;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1723306425;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1723306425 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1723306425 = cell.previousElementSibling;
#                 }
#                 input_1723306425.style.display = "none"; // hide
#
#                 toggle_input_1723306425 = function() {
#                     if (input_1723306425.style.display == "none") {
#                         input_1723306425.style.display = ""; // show
#                         link_1723306425.innerHTML = "Hide Input";
#                     } else {
#                         input_1723306425.style.display = "none"; // hide
#                         link_1723306425.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1723306425 = $("a[id='1723306425']");
#                 var cell_1723306425 = link_1723306425.parents("div.cell:first");
#                 if (cell_1723306425.length == 0) {
#                     cell_1723306425 = link_1723306425.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1723306425 = cell_1723306425.children("div.input");
#                 if (input_1723306425.length == 0) {
#                     input_1723306425 = cell_1723306425.prev("div.nbinput");
#                 }
#                 input_1723306425.hide();
#
#                 toggle_input_1723306425 = function() {
#                     if (input_1723306425.is(':hidden')) {
#                         input_1723306425.slideDown();
#                         link_1723306425[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1723306425.slideUp();
#                         link_1723306425[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1859009347" href="javascript:toggle_input_1859009347()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1859009347;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1859009347 = document.getElementById("1859009347");
#                 var cell = link_1859009347;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1859009347;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1859009347 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1859009347 = cell.previousElementSibling;
#                 }
#                 input_1859009347.style.display = "none"; // hide
#
#                 toggle_input_1859009347 = function() {
#                     if (input_1859009347.style.display == "none") {
#                         input_1859009347.style.display = ""; // show
#                         link_1859009347.innerHTML = "Hide Input";
#                     } else {
#                         input_1859009347.style.display = "none"; // hide
#                         link_1859009347.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1859009347 = $("a[id='1859009347']");
#                 var cell_1859009347 = link_1859009347.parents("div.cell:first");
#                 if (cell_1859009347.length == 0) {
#                     cell_1859009347 = link_1859009347.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1859009347 = cell_1859009347.children("div.input");
#                 if (input_1859009347.length == 0) {
#                     input_1859009347 = cell_1859009347.prev("div.nbinput");
#                 }
#                 input_1859009347.hide();
#
#                 toggle_input_1859009347 = function() {
#                     if (input_1859009347.is(':hidden')) {
#                         input_1859009347.slideDown();
#                         link_1859009347[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1859009347.slideUp();
#                         link_1859009347[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1332259477" href="javascript:toggle_input_1332259477()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1332259477;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1332259477 = document.getElementById("1332259477");
#                 var cell = link_1332259477;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1332259477;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1332259477 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1332259477 = cell.previousElementSibling;
#                 }
#                 input_1332259477.style.display = "none"; // hide
#
#                 toggle_input_1332259477 = function() {
#                     if (input_1332259477.style.display == "none") {
#                         input_1332259477.style.display = ""; // show
#                         link_1332259477.innerHTML = "Hide Input";
#                     } else {
#                         input_1332259477.style.display = "none"; // hide
#                         link_1332259477.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1332259477 = $("a[id='1332259477']");
#                 var cell_1332259477 = link_1332259477.parents("div.cell:first");
#                 if (cell_1332259477.length == 0) {
#                     cell_1332259477 = link_1332259477.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1332259477 = cell_1332259477.children("div.input");
#                 if (input_1332259477.length == 0) {
#                     input_1332259477 = cell_1332259477.prev("div.nbinput");
#                 }
#                 input_1332259477.hide();
#
#                 toggle_input_1332259477 = function() {
#                     if (input_1332259477.is(':hidden')) {
#                         input_1332259477.slideDown();
#                         link_1332259477[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1332259477.slideUp();
#                         link_1332259477[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1416072644" href="javascript:toggle_input_1416072644()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1416072644;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1416072644 = document.getElementById("1416072644");
#                 var cell = link_1416072644;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1416072644;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1416072644 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1416072644 = cell.previousElementSibling;
#                 }
#                 input_1416072644.style.display = "none"; // hide
#
#                 toggle_input_1416072644 = function() {
#                     if (input_1416072644.style.display == "none") {
#                         input_1416072644.style.display = ""; // show
#                         link_1416072644.innerHTML = "Hide Input";
#                     } else {
#                         input_1416072644.style.display = "none"; // hide
#                         link_1416072644.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1416072644 = $("a[id='1416072644']");
#                 var cell_1416072644 = link_1416072644.parents("div.cell:first");
#                 if (cell_1416072644.length == 0) {
#                     cell_1416072644 = link_1416072644.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1416072644 = cell_1416072644.children("div.input");
#                 if (input_1416072644.length == 0) {
#                     input_1416072644 = cell_1416072644.prev("div.nbinput");
#                 }
#                 input_1416072644.hide();
#
#                 toggle_input_1416072644 = function() {
#                     if (input_1416072644.is(':hidden')) {
#                         input_1416072644.slideDown();
#                         link_1416072644[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1416072644.slideUp();
#                         link_1416072644[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1768466453" href="javascript:toggle_input_1768466453()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1768466453;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1768466453 = document.getElementById("1768466453");
#                 var cell = link_1768466453;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1768466453;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1768466453 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1768466453 = cell.previousElementSibling;
#                 }
#                 input_1768466453.style.display = "none"; // hide
#
#                 toggle_input_1768466453 = function() {
#                     if (input_1768466453.style.display == "none") {
#                         input_1768466453.style.display = ""; // show
#                         link_1768466453.innerHTML = "Hide Input";
#                     } else {
#                         input_1768466453.style.display = "none"; // hide
#                         link_1768466453.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1768466453 = $("a[id='1768466453']");
#                 var cell_1768466453 = link_1768466453.parents("div.cell:first");
#                 if (cell_1768466453.length == 0) {
#                     cell_1768466453 = link_1768466453.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1768466453 = cell_1768466453.children("div.input");
#                 if (input_1768466453.length == 0) {
#                     input_1768466453 = cell_1768466453.prev("div.nbinput");
#                 }
#                 input_1768466453.hide();
#
#                 toggle_input_1768466453 = function() {
#                     if (input_1768466453.is(':hidden')) {
#                         input_1768466453.slideDown();
#                         link_1768466453[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1768466453.slideUp();
#                         link_1768466453[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="362123300" href="javascript:toggle_input_362123300()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_362123300;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_362123300 = document.getElementById("362123300");
#                 var cell = link_362123300;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_362123300;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_362123300 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_362123300 = cell.previousElementSibling;
#                 }
#                 input_362123300.style.display = "none"; // hide
#
#                 toggle_input_362123300 = function() {
#                     if (input_362123300.style.display == "none") {
#                         input_362123300.style.display = ""; // show
#                         link_362123300.innerHTML = "Hide Input";
#                     } else {
#                         input_362123300.style.display = "none"; // hide
#                         link_362123300.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_362123300 = $("a[id='362123300']");
#                 var cell_362123300 = link_362123300.parents("div.cell:first");
#                 if (cell_362123300.length == 0) {
#                     cell_362123300 = link_362123300.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_362123300 = cell_362123300.children("div.input");
#                 if (input_362123300.length == 0) {
#                     input_362123300 = cell_362123300.prev("div.nbinput");
#                 }
#                 input_362123300.hide();
#
#                 toggle_input_362123300 = function() {
#                     if (input_362123300.is(':hidden')) {
#                         input_362123300.slideDown();
#                         link_362123300[0].innerHTML = "Hide Input";
#                     } else {
#                         input_362123300.slideUp();
#                         link_362123300[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="2056189704" href="javascript:toggle_input_2056189704()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2056189704;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2056189704 = document.getElementById("2056189704");
#                 var cell = link_2056189704;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2056189704;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2056189704 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2056189704 = cell.previousElementSibling;
#                 }
#                 input_2056189704.style.display = "none"; // hide
#
#                 toggle_input_2056189704 = function() {
#                     if (input_2056189704.style.display == "none") {
#                         input_2056189704.style.display = ""; // show
#                         link_2056189704.innerHTML = "Hide Input";
#                     } else {
#                         input_2056189704.style.display = "none"; // hide
#                         link_2056189704.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2056189704 = $("a[id='2056189704']");
#                 var cell_2056189704 = link_2056189704.parents("div.cell:first");
#                 if (cell_2056189704.length == 0) {
#                     cell_2056189704 = link_2056189704.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2056189704 = cell_2056189704.children("div.input");
#                 if (input_2056189704.length == 0) {
#                     input_2056189704 = cell_2056189704.prev("div.nbinput");
#                 }
#                 input_2056189704.hide();
#
#                 toggle_input_2056189704 = function() {
#                     if (input_2056189704.is(':hidden')) {
#                         input_2056189704.slideDown();
#                         link_2056189704[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2056189704.slideUp();
#                         link_2056189704[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
